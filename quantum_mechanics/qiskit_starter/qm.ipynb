# %% [markdown]
# ### X Gate

# %%
from qiskit import QuantumCircuit
 
qc = QuantumCircuit(1)
qc.x(0)
qc.draw("mpl")

# %% [markdown]
# ### H Gate

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1)
qc.h(0)
qc.draw("mpl")
